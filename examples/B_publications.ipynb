# %% [markdown]
# # Appendix B: List of Publications
#
# This is an incomplete list of publications that made use of `DustPy`.
# If you want your publication to be listed here, please give us a note in the [Show & Tell](https://github.com/stammler/dustpy/discussions/categories/show-and-tell) category of [DustPy Discussions](https://github.com/stammler/dustpy/discussions/) or write us an [email](mailto:sebastian.stammler@gmail.com).

# %% [markdown]
# ### 2025

# %% [markdown]
# * **Compact protoplanetary discs can be produced by dead zones**
# Tong, Simin; Alexander, Richard (2025)
# _Monthly Notices of the Royal Astronomical Society, Advance Access_
# [doi: 10.1093/mnras/staf245](https://doi.org/10.1093/mnras/staf245)

# %% [markdown]
# * **Planetesimal formation in a pressure bump induced by infall**
# Zhao, Haichen; Lau, Tommy Chi Ho; Birnstiel, Tilman; Stammler, Sebastian M.; Drążkowska, Joanna (2025)
# _eprint arXiv:2501.17857_
# [doi: 10.48550/arXiv.2501.17857](https://doi.org/10.48550/arXiv.2501.17857)

# %% [markdown]
# * **Dust characterization of protoplanetary disks: a guide to multi-wavelength analyses and accurate dust mass measurements**
# Viscardi, Elena M.; Macías, Enrique; Zagaria, Francesco; Sierra, Anibal; Jiang, Haochang; Yoshida, Tomohiro; Curone, Pietro (2025)
# _eprint arXiv:2501.13877_
# [doi: 10.48550/arXiv.2501.13877](https://doi.org/10.48550/arXiv.2501.13877)

# %% [markdown]
# ### 2024

# %% [markdown]
# * **TriPoD: Tri-Population size distributions for Dust evolution: Coagulation in vertically integrated hydrodynamic simulations of protoplanetary disks**
# Pfeil, Thomas; Birnstiel, Til; Klahr, Hubert (2024)
# _Astronomy & Astrophysics, Volume 691, id.A45, 21 pp._
# [doi: 10.1051/0004-6361/202449337](https://doi.org/10.1051/0004-6361/202449337)

# %% [markdown]
# * **The rapid formation of macromolecules in irradiated ice of protoplanetary disk dust traps**
# Ligterink, Niels F. W.; Pinilla, Paola; van der Marel, Nienke; van Scheltinga, Jeroen Terwisscha; Booth, Alice S.; Alexander, Conel M. O'D.; Riebe, My E. I. (2024)
# _Nature Astronomy, Volume 8, Issue 10, pp. 1257-1263_
# [doi: 10.1038/s41550-024-02334-4](https://doi.org/10.1038/s41550-024-02334-4)

# %% [markdown]
# * **RV Measurements of Directly Imaged Brown Dwarf GQ Lup B to Search for Exosatellites**
# Horstman, Katelyn; Ruffio, Jean-Baptiste; Batygin, Konstantin; Mawet, Dimitri; Baker, Ashley; Hsu, Chih-Chun; Wang, Jason J.; Wang, Ji; Blunt, Sarah; Xuan, Jerry W.; Xin, Yinzi; Liberman, Joshua; Agrawal, Shubh; Konopacky, Quinn M.; Blake, Geoffrey A.; Do Ó, Clarissa R.; Bartos, Randall; Bond, Charlotte Z.; Calvin, Benjamin; Cetre, Sylvain; Delorme, Jacques-Robert; Doppmann, Greg; Echeverri, Daniel; Finnerty, Luke; Fitzgerald, Michael P.; Jovanovic, Nemanja; López, Ronald; Martin, Emily C.; Morris, Evan; Pezzato, Jacklyn; Ruane, Garreth; Sappey, Ben; Schofield, Tobias; Skemer, Andrew; Venenciano, Taylor; Wallace, J. Kent; Wallack, Nicole L.; Wizinowich, Peter (2024)
# _The Astronomical Journal, Volume 168, Issue 4, id.175, 10 pp._
# [doi: 10.3847/1538-3881/ad73d8](https://doi.org/10.3847/1538-3881/ad73d8)

# %% [markdown]
# * **Dust growth and evolution in protoplanetary disks**
# Birnstiel, Tilman (2024)
# _Annual Review of Astronomy and Astrophysics, Volume 62, Issue 1, pp. 157-202, 41 pp._
# [doi: 10.1146/annurev-astro-071221-052705](https://doi.org/10.1146/annurev-astro-071221-052705)

# %% [markdown]
# * **Support for fragile porous dust in a gravitationally self-regulated disk around IM Lup**
# Ueda, Takahiro; Tazaki, Ryo; Okuzumi, Satoshi; Flock, Mario; Sudarshan, Prakruti (2024)
# _Nature Astronomy, Volume 8, p. 1148-1158_
# [doi: 10.1038/s41550-024-02308-6](https://doi.org/10.1038/s41550-024-02308-6)

# %% [markdown]
# * **Sequential giant planet formation initiated by disc substructure**
# Lau, Tommy Chi Ho; Birnstiel, Til; Drążkowska, Joanna; Stammler, Sebastian (2024)
# _Astronomy & Astrophysics, Volume 688, id.A22, 12 pp._
# [doi: 10.1051/0004-6361/202450464](https://doi.org/10.1051/0004-6361/202450464)

# %% [markdown]
# * **Survival of the long-lived inner disk of PDS 70**
# Pinilla, Paola; Benisty, Myriam; Waters, Rens; Bae, Jaehan; Facchini, Stefano (2024)
# _Astronomy & Astrophysics, Volume 686, id.A135, 10 pp._
# [doi: 10.1051/0004-6361/202348707](https://doi.org/10.1051/0004-6361/202348707)

# %% [markdown]
# * **Introducing CUDISC: a 2D code for protoplanetary disc structure and evolution calculations**
# Robinson, Alfie; Booth, Richard A.; Owen, James E. (2024)
# _Monthly Notices of the Royal Astronomical Society, Volume 529, Issue 2, pp.1524-1541_
# [doi: 10.1093/mnras/stae624](https://doi.org/10.1093/mnras/stae624)

# %% [markdown]
# * **Grain-size measurements in protoplanetary disks indicate fragile pebbles and low turbulence**
# Jiang, Haochang; Macías, Enrique; Guerra-Alvarado, Osmar M.; Carrasco-González, Carlos (2024)
# _Astronomy & Astrophysics, Volume 682, id.A32, 12 pp._
# [doi: 10.1051/0004-6361/202348271](https://doi.org/10.1051/0004-6361/202348271)

# %% [markdown]
# * **The bouncing barrier revisited: Impact on key planet formation processes and observational signatures**
# Dominik, C.; Dullemond, C. P. (2024)
# _Astronomy & Astrophysics, Volume 682, id.A144, 20 pp._
# [doi: 10.1051/0004-6361/202347716](https://doi.org/10.1051/0004-6361/202347716)

# %% [markdown]
# * **Surviving the heat: multiwavelength analysis of V883 Ori reveals that dust aggregates survive the sublimation of their ice mantles**
# Houge, Adrien; Macías, Enrique; Krijt, Sebastiaan (2024)
# _Monthly Notices of the Royal Astronomical Society, Volume 527, Issue 4, pp.9668-9682_
# [doi: 10.1093/mnras/stad3758](https://doi.org/10.1093/mnras/stad3758)

# %% [markdown]
# * **The external photoevaporation of structured protoplanetary disks**
# Gárate, Matías; Pinilla, Paola; Haworth, Thomas J.; Facchini, Stefano (2024)
# _Astronomy & Astrophysics, Volume 681, id.A84, 15 pp._
# [doi: 10.1051/0004-6361/202347850](https://doi.org/10.1051/0004-6361/202347850)

# %% [markdown]
# ### 2023

# %% [markdown]
# * **Dust Coagulation Reconciles Protoplanetary Disk Observations with the Vertical Shear Instability. I. Dust Coagulation and the VSI Dead Zone**
# Pfeil, Thomas; Birnstiel, Til; Klahr, Hubert (2023)
# _The Astrophysical Journal, Volume 959, Issue 2, id.121, 19 pp._
# [doi: 10.3847/1538-4357/ad00af](https://doi.org/10.3847/1538-4357/ad00af)

# %% [markdown]
# * **Constraints on the Dust Size Distributions in the HD 163296 Disk from the Difference of the Apparent Dust Ring Widths between Two ALMA Bands**
# Doi, Kiyoaki; Kataoka, Akimasa (2023)
# _The Astrophysical Journal, Volume 957, Issue 1, id.11, 24 pp._
# [doi: 10.3847/1538-4357/acf5df](https://doi.org/10.3847/1538-4357/acf5df)

# %% [markdown]
# * **Millimeter emission in photoevaporating disks is determined by early substructures**
# Gárate, Matías; Birnstiel, Til; Pinilla, Paola; Andrews, Sean M.; Franz, Raphael; Stammler, Sebastian Markus; Picogna, Giovanni; Ercolano, Barbara; Miotello, Anna; Kurtovic, Nicolás T. (2023)
# _Astronomy & Astrophysics, Volume 679, id.A15, 17 pp._
# [doi: 10.1051/0004-6361/202244436](https://doi.org/10.1051/0004-6361/202244436)

# %% [markdown]
# * **Coagulation-Fragmentation Equilibrium for Charged Dust: Abundance of Submicron Grains Increases Dramatically in Protoplanetary Disks**
# Akimkin, Vitaly; Ivlev, Alexei V.; Caselli, Paola; Gong, Munan; Silsbee, Kedron (2023)
# _The Astrophysical Journal, Volume 953, Issue 1, id.72, 10 pp._
# [doi: 10.3847/1538-4357/ace2c5](https://doi.org/10.3847/1538-4357/ace2c5)

# %% [markdown]
# * **The impact of dust evolution on the dead zone outer edge in magnetized protoplanetary disks**
# Delage, Timmy N.; Gárate, Matías; Okuzumi, Satoshi; Yang, Chao-Chin; Pinilla, Paola; Flock, Mario; Stammler, Sebastian Markus; Birnstiel, Tilman (2023)
# _Astronomy & Astrophysics, Volume 674, id.A190, 23 pp._
# [doi: 10.1051/0004-6361/202244731](https://doi.org/10.1051/0004-6361/202244731)

# %% [markdown]
# * **Revisiting collisional dust growth in Class 0/I protostellar disks: Sweep-up can convert a few** $10\,M_\oplus$ **of dust into kg pebbles in 0.1 Myr**
# Xu, Wenrui; Armitage, Philip J. (2023)
# _The Astrophysical Journal, Volume 946, Issue 2, id.94, 12 pp._
# [doi: 10.3847/1538-4357/acb7e5](https://doi.org/10.3847/1538-4357/acb7e5)

# %% [markdown]
# * **Leaky dust traps: How fragmentation impacts dust filtering by planets**
# Stammler, Sebastian Markus; Lichtenberg, Tim; Drążkowska, Joanna; Birnstiel, Tilman (2023)
# _Astronomy & Astrophysics, Volume 670, id.L5, 8 pp._
# [doi: 10.1051/0004-6361/202245512](https://doi.org/10.1051/0004-6361/202245512)

# %% [markdown]
# ### 2022

# %% [markdown]
# * **The impact of dynamic pressure bumps on the observational properties of protoplanetary disks**
# Stadler, Jochen; Gárate, Matías; Pinilla, Paola; Lenz, Christian; Dullemond, Cornelis P.; Birnstiel, Til; Stammler, Sebastian M. (2022)
# _Astronomy & Astrophysics, Volume 668, id.A104, 22 pp._
# [doi: 10.1051/0004-6361/202243338](https://doi.org/10.1051/0004-6361/202243338)

# %% [markdown]
# * **Rapid Formation of Massive Planetary Cores in a Pressure Bump**
# Lau, Tommy Chi Ho; Drążkowska, Joanna; Stammler, Sebastian M.; Birnstiel, Tilman; Dullemond, Cornelis P. (2022)
# _Astronomy & Astrophysics, Volume 668, id.A170, 15 pp._
# [doi: 10.1051/0004-6361/202244864](https://doi.org/10.1051/0004-6361/202244864)

# %% [markdown]
# * **A Neural Network Subgrid Model of the Early Stages of Planet Formation**
# Pfeil, Thomas; Cranmer, Miles; Ho, Shirley; Armitage, Philip J.; Birnstiel, Tilman; Klahr, Hubert (2022)
# _Machine Learning and the Physical Sciences workshop, NeurIPS 2022_
# [doi: 10.48550/arXiv.2211.04160](https://doi.org/10.48550/arXiv.2211.04160)

# %% [markdown]
# * **First Steps of Planet Formation Around Very Low Mass Stars and Brown Dwarfs**
# Pinilla, Paola (2022)
# _The European Physical Journal Plus, Volume 137, Issue 11, article id.1206_
# [doi: 10.1140/epjp/s13360-022-03384-1](https://doi.org/10.1140/epjp/s13360-022-03384-1)

# %% [markdown]
# ### 2021

# %% [markdown]
# * **The formation of wide exoKuiper belts from migrating dust traps**
# Miller, E.; Marino, S.; Stammler, S. M.; Pinilla, P.; Lenz, C.; Birnstiel, T.; Henning, Th (2021)
# _Monthly Notices of the Royal Astronomical Society, Volume 508, Issue 4, pp.5638-5656_
# [doi: 10.1093/mnras/stab2935](https://doi.org/10.1093/mnras/stab2935)

# %% [markdown]
# * **Large gaps and high accretion rates in photoevaporative transition disks with a dead zone**
# Gárate, Matías; Delage, Timmy N.; Stadler, Jochen; Pinilla, Paola; Birnstiel, Til; Stammler, Sebastian M.; Picogna, Giovanni; Ercolano, Barbara; Franz, Raphael; Lenz, Christian (2021)
# _Astronomy & Astrophysics, Volume 655, id.A18, 16 pp._
# [doi: 10.1051/0004-6361/202141444](https://doi.org/10.1051/0004-6361/202141444)

# %% [markdown]
# * **A bright inner disk and structures in the transition disk around the very low-mass star CIDA 1**
# Pinilla, P. ; Kurtovic, N. T. ; Benisty, M. ; Manara, C. F. ; Natta, A. ; Sanchis, E. ; Tazzari, M. ; Stammler, S. M. ; Ricci, L. ; Testi, L. (2021)
# _Astronomy & Astrophysics, Volume 649, id.A122, 13 pp._
# [doi: 10.1051/0004-6361/202140371](https://doi.org/10.1051/0004-6361/202140371)

# %% [markdown]
# * **How dust fragmentation may be beneficial to planetary growth by pebble accretion**
# Drążkowska, Joanna; Stammler, Sebastian M.; Birnstiel, Til (2021)
# _Astronomy & Astrophysics, Volume 647, id.A15, 11 pp._
# [doi: 10.1051/0004-6361/202039925](https://doi.org/10.1051/0004-6361/202039925)

# %% [markdown]
# * **Growing and trapping pebbles with fragile collisions of particles in protoplanetary disks**
# Pinilla, Paola; Lenz, Christian T.; Stammler, Sebastian M. (2021)
# _Astronomy & Astrophysics, Volume 645, id.A70, 16 pp._
# [doi: 10.1051/0004-6361/202038920](https://doi.org/10.1051/0004-6361/202038920)

# %% [markdown]
# ### 2020

# %% [markdown]
# * **Constraining the parameter space for the solar nebula. The effect of disk properties on planetesimal formation**
# Lenz, Christian T.; Klahr, Hubert; Birnstiel, Tilman; Kretke, Katherine; Stammler, Sebastian (2020)
# _Astronomy & Astrophysics, Volume 640, id.A61, 21 pp._
# [doi: 10.1051/0004-6361/202037878](https://doi.org/10.1051/0004-6361/202037878)

# %% [markdown]
# * **Gas accretion damped by dust back-reaction at the snow line**
# Gárate, Matías; Birnstiel, Til; Drążkowska, Joanna; Stammler, Sebastian Markus (2020)
# _Astronomy & Astrophysics, Volume 635, id.A149, 18 pp._
# [doi: 10.1051/0004-6361/201936067](https://doi.org/10.1051/0004-6361/201936067)

# %% [markdown]
# ### 2019

# %% [markdown]
# * **Including Dust Coagulation in Hydrodynamic Models of Protoplanetary Disks: Dust Evolution in the Vicinity of a Jupiter-mass Planet**
# Drążkowska, Joanna; Li, Shengtai; Birnstiel, Til; Stammler, Sebastian M.; Li, Hui (2019)
# _The Astrophysical Journal, Volume 885, Issue 1, article id. 91, 10 pp._
# [doi: 10.3847/1538-4357/ab46b7](https://doi.org/10.3847/1538-4357/ab46b7)

# %% [markdown]
# * **The DSHARP Rings: Evidence of Ongoing Planetesimal Formation?**
# Stammler, Sebastian M.; Drążkowska, Joanna; Birnstiel, Til; Klahr, Hubert; Dullemond, Cornelis P.; Andrews, Sean M. (2019)
# _The Astrophysical Journal Letters, Volume 884, Issue 1, article id. L5, 7 pp._
# [doi: 10.3847/2041-8213/ab4423](https://doi.org/10.3847/2041-8213/ab4423)

# %% [markdown]
# * **The Dimming of RW Auriga: Is Dust Accretion Preceding an Outburst?**
# Gárate, Matías; Birnstiel, Til; Stammler, Sebastian Markus; Günther, Hans Moritz (2019)
# _The Astrophysical Journal, Volume 871, Issue 1, article id. 53, 16 pp._
# [doi: 10.3847/1538-4357/aaf4fc](https://doi.org/10.3847/1538-4357/aaf4fc)
